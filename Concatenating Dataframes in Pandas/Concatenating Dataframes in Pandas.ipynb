# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
outlet_size_high=pd.read_csv("C:\\Users\\User\\Desktop\\Data-Science\\Concatenating Dataframes in Pandas\\outlet_size_high.csv")

# %%
outlet_size_medium=pd.read_csv("C:\\Users\\User\\Desktop\\Data-Science\\Concatenating Dataframes in Pandas\\outlet_size_medium.csv")

# %%
outlet_size_small=pd.read_csv("C:\\Users\\User\\Desktop\\Data-Science\\Concatenating Dataframes in Pandas\\outlet_size_small.csv")

# %%
outlet_size_high.shape,outlet_size_medium.shape,outlet_size_small.shape
# Out:
# ((932, 9), (2793, 9), (2388, 9))

# %%
outlet_size_high.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           NCD19         8.93          Low Fat         0.000000
# 1           FDO10        13.65          Regular         0.012741
# 2           FDF32        16.35          Low Fat         0.068024
# 3           FDN22        18.85          Regular         0.138190
# 4           DRJ59        11.65          low fat         0.019356
#
#                Item_Type  Item_MRP Outlet_Identifier        Outlet_Type  \
# 0              Household   53.8614            OUT013  Supermarket Type1
# 1            Snack Foods   57.6588            OUT013  Supermarket Type1
# 2  Fruits and Vegetables  196.4426            OUT013  Supermarket Type1
# 3            Snack Foods  250.8724            OUT013  Supermarket Type1
# 4            Hard Drinks   39.1164            OUT013  Supermarket Type1
#
#    Item_Outlet_Sales
# 0           994.7052
# 1           343.5528
# 2          1977.4260
# 3          3775.0860
# 4           308.9312

# %%
outlet_size_medium.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15        9.300          Low Fat         0.016047
# 1           DRC01        5.920          Regular         0.019278
# 2           FDN15       17.500          Low Fat         0.016760
# 3           FDP36       10.395          Regular         0.000000
# 4           FDP10          NaN          Low Fat         0.127470
#
#       Item_Type  Item_MRP Outlet_Identifier        Outlet_Type  \
# 0         Dairy  249.8092            OUT049  Supermarket Type1
# 1   Soft Drinks   48.2692            OUT018  Supermarket Type2
# 2          Meat  141.6180            OUT049  Supermarket Type1
# 3  Baking Goods   51.4008            OUT018  Supermarket Type2
# 4   Snack Foods  107.7622            OUT027  Supermarket Type3
#
#    Item_Outlet_Sales
# 0          3735.1380
# 1           443.4228
# 2          2097.2700
# 3           556.6088
# 4          4022.7636

# %%
outlet_size_small.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0           FDA03        18.50          Regular         0.045464        Dairy
# 1           FDS46        17.60          Regular         0.047257  Snack Foods
# 2           FDP49         9.00          Regular         0.069089    Breakfast
# 3           FDU02        13.35          Low Fat         0.102492        Dairy
# 4           NCB30        14.60          Low Fat         0.025698    Household
#
#    Item_MRP Outlet_Identifier        Outlet_Type  Item_Outlet_Sales
# 0  144.1102            OUT046  Supermarket Type1          2187.1530
# 1  119.6782            OUT046  Supermarket Type1          2145.2076
# 2   56.3614            OUT046  Supermarket Type1          1547.3192
# 3  230.5352            OUT035  Supermarket Type1          2748.4224
# 4  196.5084            OUT035  Supermarket Type1          1587.2672

# %%
all_df=[outlet_size_high,outlet_size_medium,outlet_size_small]

# %%
df=pd.concat(all_df,axis=0)

# %%
df
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              NCD19         8.93          Low Fat         0.000000
# 1              FDO10        13.65          Regular         0.012741
# 2              FDF32        16.35          Low Fat         0.068024
# 3              FDN22        18.85          Regular         0.138190
# 4              DRJ59        11.65          low fat         0.019356
# ...              ...          ...              ...              ...
# 2383           FDN58        13.80          Regular         0.056862
# 2384           FDH31        12.00          Regular         0.020407
# 2385           FDF53        20.75              reg         0.083607
# 2386           NCJ29        10.60          Low Fat         0.035186
# 2387           DRG01        14.80          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier        Outlet_Type  \
# ...

# %%
df.shape
# Out:
# (6113, 9)

# %%
my_dict={
    'roll_no': [ 102, 101, 104, 103, 105],
    'name' : ['Aravind', 'Rahul', 'Prateek', 'Piyuesh', 'Kartik'],
    'grade': ['B', 'B', 'A', 'C', 'A'],
    'marks': [ 15, 15, 20, 4, 22],
    'city' : ['Gurugram', 'Delhi', 'Delhi', 'Gurugram', 'Hyderabad']
}

# %%
phone_dict={ 'phone_no' : [212202, 202021, 212334, 213431, 211721]}

# %%
phone_no = pd.DataFrame(phone_dict)
phone_no
# Out:
#    phone_no
# 0    212202
# 1    202021
# 2    212334
# 3    213431
# 4    211721

# %%
sample_dataframe = pd.DataFrame(my_dict)
sample_dataframe
# Out:
#    roll_no     name grade  marks       city
# 0      102  Aravind     B     15   Gurugram
# 1      101    Rahul     B     15      Delhi
# 2      104  Prateek     A     20      Delhi
# 3      103  Piyuesh     C      4   Gurugram
# 4      105   Kartik     A     22  Hyderabad

# %%
al_df=[sample_dataframe,phone_no]

# %%
combined = pd.concat([sample_dataframe,phone_no], axis=1)
combined
# Out:
#    roll_no     name grade  marks       city  phone_no
# 0      102  Aravind     B     15   Gurugram    212202
# 1      101    Rahul     B     15      Delhi    202021
# 2      104  Prateek     A     20      Delhi    212334
# 3      103  Piyuesh     C      4   Gurugram    213431
# 4      105   Kartik     A     22  Hyderabad    211721
