# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
import datetime

# %%
df=pd.read_csv("C:\\Users\\User\\Desktop\\Data-Science\\Dataset\\time_series.csv")

# %%
df.head()
# Out:
#    ID          Datetime  Count
# 0   0  25-08-2012 00:00      8
# 1   1  25-08-2012 01:00      2
# 2   2  25-08-2012 02:00      6
# 3   3  25-08-2012 03:00      2
# 4   4  25-08-2012 04:00      2

# %%
df.value_counts().sum()
# Out:
# 18288

# %%
df.isnull().sum()
# Out:
# ID          0
# Datetime    0
# Count       0
# dtype: int64

# %%
df.dtypes
# Out:
# ID           int64
# Datetime    object
# Count        int64
# dtype: object

# %% [markdown]
# # Change the Data Type to DateTime

# %%
df.Datetime = pd.to_datetime(df.Datetime)

# %%
df.dtypes
# Out:
# ID                   int64
# Datetime    datetime64[ns]
# Count                int64
# dtype: object

# %%
df.head()
# Out:
#    ID            Datetime  Count
# 0   0 2012-08-25 00:00:00      8
# 1   1 2012-08-25 01:00:00      2
# 2   2 2012-08-25 02:00:00      6
# 3   3 2012-08-25 03:00:00      2
# 4   4 2012-08-25 04:00:00      2

# %%
df.Datetime.apply(lambda x: x.day_name())
# Out:
# 0        Saturday
# 1        Saturday
# 2        Saturday
# 3        Saturday
# 4        Saturday
#            ...
# 18283    Thursday
# 18284    Thursday
# 18285    Thursday
# 18286    Thursday
# 18287    Thursday
# Name: Datetime, Length: 18288, dtype: object

# %%
df.Datetime.apply(lambda x: x.month_name())
# Out:
# 0           August
# 1           August
# 2           August
# 3           August
# 4           August
#            ...
# 18283    September
# 18284    September
# 18285    September
# 18286    September
# 18287    September
# Name: Datetime, Length: 18288, dtype: object

# %%
df2=pd.read_csv("C:\\Users\\User\\Desktop\\Data-Science\\Dataset\\time_series_2.csv")

# %%
df2.head()
# Out:
#    ID      Datetime  Count
# 0   0  25 Aug 2012       8
# 1   1  25 Aug 2012       2
# 2   2  25 Aug 2012       6
# 3   3  25 Aug 2012       2
# 4   4  25 Aug 2012       2

# %%
df2.Datetime = pd.to_datetime(df2.Datetime,format="%d %b %Y ")

# %%
df2.head()
# Out:
#    ID   Datetime  Count
# 0   0 2012-08-25      8
# 1   1 2012-08-25      2
# 2   2 2012-08-25      6
# 3   3 2012-08-25      2
# 4   4 2012-08-25      2

# %% [markdown]
# # Time Based Feature

# %%
df.head()
# Out:
#    ID            Datetime  Count
# 0   0 2012-08-25 00:00:00      8
# 1   1 2012-08-25 01:00:00      2
# 2   2 2012-08-25 02:00:00      6
# 3   3 2012-08-25 03:00:00      2
# 4   4 2012-08-25 04:00:00      2

# %%
df['month']=df.Datetime.dt.month

# %%
df['month_name']=df.Datetime.dt.month_name()

# %%
df['day_name']=df.Datetime.dt.day_name()

# %%
df['day_of_week']=df.Datetime.dt.dayofweek

# %%
df['day_of_year']=df.Datetime.dt.dayofyear

# %%
df.head()
# Out:
#    ID            Datetime  Count  month month_name  day_name  day_of_week  \
# 0   0 2012-08-25 00:00:00      8      8     August  Saturday            5
# 1   1 2012-08-25 01:00:00      2      8     August  Saturday            5
# 2   2 2012-08-25 02:00:00      6      8     August  Saturday            5
# 3   3 2012-08-25 03:00:00      2      8     August  Saturday            5
# 4   4 2012-08-25 04:00:00      2      8     August  Saturday            5
#
#    day_of_year
# 0          238
# 1          238
# 2          238
# 3          238
# 4          238

# %%
df["today"]=pd.to_datetime(datetime.date.today())

# %%
df.head()
# Out:
#    ID            Datetime  Count  month month_name  day_name  day_of_week  \
# 0   0 2012-08-25 00:00:00      8      8     August  Saturday            5
# 1   1 2012-08-25 01:00:00      2      8     August  Saturday            5
# 2   2 2012-08-25 02:00:00      6      8     August  Saturday            5
# 3   3 2012-08-25 03:00:00      2      8     August  Saturday            5
# 4   4 2012-08-25 04:00:00      2      8     August  Saturday            5
#
#    day_of_year      today
# 0          238 2022-06-27
# 1          238 2022-06-27
# 2          238 2022-06-27
# 3          238 2022-06-27
# 4          238 2022-06-27

# %%
df_difference=df["today"]-df["Datetime"]

# %%
df_difference.apply(lambda x: x.days)
# Out:
# 0        3593
# 1        3592
# 2        3592
# 3        3592
# 4        3592
#          ...
# 18283    2831
# 18284    2831
# 18285    2831
# 18286    2831
# 18287    2831
# Length: 18288, dtype: int64

# %%
df["day_of_difference"]=df_difference.apply(lambda x: x.days)

# %%
df
# Out:
#           ID            Datetime  Count  month month_name  day_name  \
# 0          0 2012-08-25 00:00:00      8      8     August  Saturday
# 1          1 2012-08-25 01:00:00      2      8     August  Saturday
# 2          2 2012-08-25 02:00:00      6      8     August  Saturday
# 3          3 2012-08-25 03:00:00      2      8     August  Saturday
# 4          4 2012-08-25 04:00:00      2      8     August  Saturday
# ...      ...                 ...    ...    ...        ...       ...
# 18283  18283 2014-09-25 19:00:00    868      9  September  Thursday
# 18284  18284 2014-09-25 20:00:00    732      9  September  Thursday
# 18285  18285 2014-09-25 21:00:00    702      9  September  Thursday
# 18286  18286 2014-09-25 22:00:00    580      9  September  Thursday
# 18287  18287 2014-09-25 23:00:00    534      9  September  Thursday
#
#        day_of_week  day_of_year      today  day_of_difference
# 0                5          238 2022-06-27               3593
# ...

# %% [markdown]
# # Challenges with time data

# %%
df["Asia_TimeZone"]=df.Datetime.dt.tz_localize("Asia/Calcutta")

# %%
df
# Out:
#           ID            Datetime  Count  month month_name  day_name  \
# 0          0 2012-08-25 00:00:00      8      8     August  Saturday
# 1          1 2012-08-25 01:00:00      2      8     August  Saturday
# 2          2 2012-08-25 02:00:00      6      8     August  Saturday
# 3          3 2012-08-25 03:00:00      2      8     August  Saturday
# 4          4 2012-08-25 04:00:00      2      8     August  Saturday
# ...      ...                 ...    ...    ...        ...       ...
# 18283  18283 2014-09-25 19:00:00    868      9  September  Thursday
# 18284  18284 2014-09-25 20:00:00    732      9  September  Thursday
# 18285  18285 2014-09-25 21:00:00    702      9  September  Thursday
# 18286  18286 2014-09-25 22:00:00    580      9  September  Thursday
# 18287  18287 2014-09-25 23:00:00    534      9  September  Thursday
#
#        day_of_week  day_of_year      today  day_of_difference  \
# 0                5          238 2022-06-27               3593
# ...

# %%
df["UTC_TimeZone"]=df.Asia_TimeZone.dt.tz_convert("UTC")

# %%
df
# Out:
#           ID            Datetime  Count  month month_name  day_name  \
# 0          0 2012-08-25 00:00:00      8      8     August  Saturday
# 1          1 2012-08-25 01:00:00      2      8     August  Saturday
# 2          2 2012-08-25 02:00:00      6      8     August  Saturday
# 3          3 2012-08-25 03:00:00      2      8     August  Saturday
# 4          4 2012-08-25 04:00:00      2      8     August  Saturday
# ...      ...                 ...    ...    ...        ...       ...
# 18283  18283 2014-09-25 19:00:00    868      9  September  Thursday
# 18284  18284 2014-09-25 20:00:00    732      9  September  Thursday
# 18285  18285 2014-09-25 21:00:00    702      9  September  Thursday
# 18286  18286 2014-09-25 22:00:00    580      9  September  Thursday
# 18287  18287 2014-09-25 23:00:00    534      9  September  Thursday
#
#        day_of_week  day_of_year      today  day_of_difference  \
# 0                5          238 2022-06-27               3593
# ...

# %%
df[["Asia_TimeZone","UTC_TimeZone"]].head()
# Out:
#               Asia_TimeZone              UTC_TimeZone
# 0 2012-08-25 00:00:00+05:30 2012-08-24 18:30:00+00:00
# 1 2012-08-25 01:00:00+05:30 2012-08-24 19:30:00+00:00
# 2 2012-08-25 02:00:00+05:30 2012-08-24 20:30:00+00:00
# 3 2012-08-25 03:00:00+05:30 2012-08-24 21:30:00+00:00
# 4 2012-08-25 04:00:00+05:30 2012-08-24 22:30:00+00:00

# %%
df["Asia_TimeZone"][18287]
# Out:
# Timestamp('2014-09-25 23:00:00+0530', tz='Asia/Calcutta')

# %%
df["UTC_TimeZone"][18287]
# Out:
# Timestamp('2014-09-25 17:30:00+0000', tz='UTC')

# %% [markdown]
# # Reading Data With UNIX TimeStamp

# %%
df3=pd.read_csv("C:\\Users\\User\\Desktop\\Data-Science\\Dataset\\data_with_timestamp.csv")

# %%
df3.head()
# Out:
#    ID   timestamp  Count
# 0   0  1345852800      8
# 1   1  1345856400      2
# 2   2  1345860000      6
# 3   3  1345863600      2
# 4   4  1345867200      2

# %% [markdown]
# # Unix to Datetime

# %%
df3["timestamp"]=pd.to_datetime(df3.timestamp,unit="s")

# %%
df3.head()
# Out:
#    ID           timestamp  Count
# 0   0 2012-08-25 00:00:00      8
# 1   1 2012-08-25 01:00:00      2
# 2   2 2012-08-25 02:00:00      6
# 3   3 2012-08-25 03:00:00      2
# 4   4 2012-08-25 04:00:00      2
